# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data_df = pd.DataFrame(purchase_data)
purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [780 rows x 7 columns]

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
#total number of players using int value for calculating value - shows 576 players

sn_player = len(purchase_data_df["SN"].value_counts())
sn_player_count = pd.DataFrame([sn_player], columns = ["Total Players"])
sn_player_count
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
## all of these you will probably have to len over to get the data correctly

#get unique values - item name is an object
unique_items = purchase_data_df["Item Name"].unique()
#unique_items #listed every unique item name

#count - 
count_item = len(purchase_data_df["Item Name"].value_counts())
count_item
#provides a value of 179

#get average purchase price - float
price_average = purchase_data_df["Price"].mean()
price_average
#gives result 3.050987179487176


#get total number of purchases- float
purchase_count = purchase_data_df["Purchase ID"].count()
purchase_count
#gives result of 780

#get total revenue - "price" is a float
revenue_total = purchase_data_df["Price"].sum()
revenue_total
#gives result of 2379.77


#average total per person


#Purchasing Analysis dictionary to dataframe 
purchase_dicts = ({"Number of Unique Items": [count_item],
                        "Average Purchase Price": [price_average],
                        "Total Number of Purchases": [purchase_count],
                        "Total Revenue": [revenue_total]})
pur_analysis_df = pd.DataFrame(purchase_dicts)
pur_analysis_df.style.format({"Average Purchase Price": "${0:.2f}",
                             "Total Revenue":"${0:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_84457_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Number of Unique Items</th>
#       <th class="col_heading level0 col1" >Average Purchase Price</th>
#       <th class="col_heading level0 col2" >Total Number of Purchases</th>
#       <th class="col_heading level0 col3" >Total Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84457_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84457_row0_col0" class="data row0 col0" >179</td>
#       <td id="T_84457_row0_col1" class="data row0 col1" >$3.05</td>
#       <td id="T_84457_row0_col2" class="data row0 col2" >780</td>
#       <td id="T_84457_row0_col3" class="data row0 col3" >$2379.77</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
player_solo_df = purchase_data_df.drop_duplicates(subset=["SN"])
player_solo_df.count
gender_df = player_solo_df["Gender"].value_counts()
gender_df.astype(float)
#gives 484 males, 81 females, 11 other
 
#Lists of values
totals = [gender_df[0],gender_df[1],gender_df[2]]
playercount = len(player_solo_df["SN"].value_counts())
#playercount-576

#percent of players
percent_players = [(gender_df[0]/playercount), (gender_df[1]/playercount),(gender_df[2]/playercount)]


#gender demograph to dataframe
gender_demo_df = pd.DataFrame({"Total Count" : gender_df,"Percentage of Players" : percent_players})
gender_demo_df.style.format({"Percentage of Players": "{:.2%}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_b081b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Count</th>
#       <th class="col_heading level0 col1" >Percentage of Players</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b081b_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_b081b_row0_col0" class="data row0 col0" >484</td>
#       <td id="T_b081b_row0_col1" class="data row0 col1" >84.03%</td>
#     </tr>
#     <tr>
#       <th id="T_b081b_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_b081b_row1_col0" class="data row1 col0" >81</td>
#       <td id="T_b081b_row1_col1" class="data row1 col1" >14.06%</td>
#     </tr>
#     <tr>
#       <th id="T_b081b_level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#       <td id="T_b081b_row2_col0" class="data row2 col0" >11</td>
#       <td id="T_b081b_row2_col1" class="data row2 col1" >1.91%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Group by gender and SN
groupby_gender = purchase_data_df.groupby("Gender")
#groupby_gender


#Arrange for counts and means(113,652, 15)

gender_purchase_count=groupby_gender["Purchase ID"].count()
gender_purchase_count

#price_average(3.20, 3.02, 3.35)
gender_price_av=groupby_gender["Price"].mean()
gender_price_av

#purchase_sum(361.94, 1967.64, 50.19)
gender_sum=groupby_gender["Price"].sum()
gender_sum

groupby_sn = purchase_data_df.groupby("SN")
unique_sn = groupby_gender["SN"].nunique()
#sn_sum
sn_sum = groupby_sn["Price"].sum
sn_sum

##sn average (4.47, 4.07, 4.56)
sn_average=(groupby_gender["Price"].sum()/unique_sn)
sn_average


#build DF for display
purchase_analysis_df = pd.DataFrame({"Purchase Count": gender_purchase_count, 
                                    "Average Purchase Price": gender_price_av,
                                    "Total Purchase Value":gender_sum,
                                    "Avg Purchase Total per Person": sn_average})

purchase_analysis_df["Average Purchase Price"].astype(float)
purchase_analysis_df["Total Purchase Value"].astype(float)
#Set index as gender
purchase_analysis_df.index.name = "Gender"

#format DF for 
purchase_analysis_df.style.format({"Total Purchase Value":"${0:.2f}",
                                  "Average Purchase Price":"${0:.2f}",
                                  "Avg Purchase Total per Person":"${0:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ddbe_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Purchase Count</th>
#       <th class="col_heading level0 col1" >Average Purchase Price</th>
#       <th class="col_heading level0 col2" >Total Purchase Value</th>
#       <th class="col_heading level0 col3" >Avg Purchase Total per Person</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ddbe_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_1ddbe_row0_col0" class="data row0 col0" >113</td>
#       <td id="T_1ddbe_row0_col1" class="data row0 col1" >$3.20</td>
#       <td id="T_1ddbe_row0_col2" class="data row0 col2" >$361.94</td>
#       <td id="T_1ddbe_row0_col3" class="data row0 col3" >$4.47</td>
#     </tr>
#     <tr>
#       <th id="T_1ddbe_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_1ddbe_row1_col0" class="data row1 col0" >652</td>
#       <td id="T_1ddbe_row1_col1" class="data row1 col1" >$3.02</td>
#       <td id="T_1ddbe_row1_col2" class="data row1 col2" >$1967.64</td>
#       <td id="T_1ddbe_row1_col3" class="data row1 col3" >$4.07</td>
#     </tr>
#     <tr>
#       <th id="T_1ddbe_level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#       <td id="T_1ddbe_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_1ddbe_row2_col1" class="data row2 col1" >$3.35</td>
#       <td id="T_1ddbe_row2_col2" class="data row2 col2" >$50.19</td>
#       <td id="T_1ddbe_row2_col3" class="data row2 col3" >$4.56</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#criterea for bin
age_bins = [0, 9, 14, 19, 24, 29, 34, 39, 100]
age_name = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#sort age values into bins
purchase_data_df["Age Group"] = pd.cut(purchase_data_df["Age"], age_bins, labels=age_name)

#create df with age groups
age_df = purchase_data_df.groupby("Age Group")

#counts by age - 17, 22, 107, 258, 77, 52, 31, 12)
age_count = age_df["SN"].nunique()
age_count

#percent by age - 2.95, 3.81, 18.57, 44.79, 13.36, 9.02, 5.38, 2.08
age_percent = (age_count/playercount)
age_percent

#create df with counts and percents
age_demo = pd.DataFrame({"Total Count": age_count, 
                        "Percentage of Players": age_percent})

#age group index - no index
age_demo.index.name = None

#formatpercent ({"Percentage of Players":"{:,.2%}"})
age_demo.style.format({"Percentage of Players":"{:.2%}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_8c1dd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Count</th>
#       <th class="col_heading level0 col1" >Percentage of Players</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c1dd_level0_row0" class="row_heading level0 row0" ><10</th>
#       <td id="T_8c1dd_row0_col0" class="data row0 col0" >17</td>
#       <td id="T_8c1dd_row0_col1" class="data row0 col1" >2.95%</td>
#     </tr>
#     <tr>
#       <th id="T_8c1dd_level0_row1" class="row_heading level0 row1" >10-14</th>
#       <td id="T_8c1dd_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_8c1dd_row1_col1" class="data row1 col1" >3.82%</td>
#     </tr>
#     <tr>
#       <th id="T_8c1dd_level0_row2" class="row_heading level0 row2" >15-19</th>
#       <td id="T_8c1dd_row2_col0" class="data row2 col0" >107</td>
#       <td id="T_8c1dd_row2_col1" class="data row2 col1" >18.58%</td>
#     </tr>
#     <tr>
#       <th id="T_8c1dd_level0_row3" class="row_heading level0 row3" >20-24</th>
#       <td id="T_8c1dd_row3_col0" class="data row3 col0" >258</td>
#       <td id="T_8c1dd_row3_col1" class="data row3 col1" >44.79%</td>
#     </tr>
#     <tr>
#       <th id="T_8c1dd_level0_row4" class="row_heading level0 row4" >25-29</th>
#       <td id="T_8c1dd_row4_col0" class="data row4 col0" >77</td>
#       <td id="T_8c1dd_row4_col1" class="data row4 col1" >13.37%</td>
#     </tr>
#     <tr>
#       <th id="T_8c1dd_level0_row5" class="row_heading level0 row5" >30-34</th>
#       <td id="T_8c1dd_row5_col0" class="data row5 col0" >52</td>
#       <td id="T_8c1dd_row5_col1" class="data row5 col1" >9.03%</td>
#     </tr>
#     <tr>
#       <th id="T_8c1dd_level0_row6" class="row_heading level0 row6" >35-39</th>
#       <td id="T_8c1dd_row6_col0" class="data row6 col0" >31</td>
#       <td id="T_8c1dd_row6_col1" class="data row6 col1" >5.38%</td>
#     </tr>
#     <tr>
#       <th id="T_8c1dd_level0_row7" class="row_heading level0 row7" >40+</th>
#       <td id="T_8c1dd_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_8c1dd_row7_col1" class="data row7 col1" >2.08%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#data is binned already above
#count purch by age group -23, 28, 136, 365, 101, 73, 41, 13
purch_age_count = age_df["Price"].count()
purch_age_count

#average purch price age group -3.35, 2.95, 3.03, 3.05, 2.90, 2.93, 3.60, 2.94
purch_age_av = age_df["Price"].mean()
purch_age_av

#sum total purch value by age group- 77.13, 82.78, 412.89, 1114.06, 293, 214, 147.67, 38.24
person_age_totals = age_df["Price"].sum()
person_age_totals

#average total purch per person - 4.53, 3.76, 3.85, 4.31, 3.80, 4.11, 4.76, 3.18
person_ave_age_totals = person_age_totals/age_count
person_ave_age_totals

#build df with values
age_purch_analysis_df = pd.DataFrame({"Purchase Count": purch_age_count,
                                 "Average Purchase Price": purch_age_av,
                                 "Total Purchase Value": person_age_totals,
                                 "Average Purchase Total per Person": person_ave_age_totals})

#provide index as age ranges
age_purch_analysis_df.index.name = "Age Ranges"

#format with currency "{:.2%}"})
age_purch_analysis_df.style.format({"Total Purchase Value": "${:.2f}",
                                  "Average Purchase Price":"${:.2f}",
                                  "Average Purchase Total per Person": "${:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a14f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Purchase Count</th>
#       <th class="col_heading level0 col1" >Average Purchase Price</th>
#       <th class="col_heading level0 col2" >Total Purchase Value</th>
#       <th class="col_heading level0 col3" >Average Purchase Total per Person</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Ranges</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a14f3_level0_row0" class="row_heading level0 row0" ><10</th>
#       <td id="T_a14f3_row0_col0" class="data row0 col0" >23</td>
#       <td id="T_a14f3_row0_col1" class="data row0 col1" >$3.35</td>
#       <td id="T_a14f3_row0_col2" class="data row0 col2" >$77.13</td>
#       <td id="T_a14f3_row0_col3" class="data row0 col3" >$4.54</td>
#     </tr>
#     <tr>
#       <th id="T_a14f3_level0_row1" class="row_heading level0 row1" >10-14</th>
#       <td id="T_a14f3_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_a14f3_row1_col1" class="data row1 col1" >$2.96</td>
#       <td id="T_a14f3_row1_col2" class="data row1 col2" >$82.78</td>
#       <td id="T_a14f3_row1_col3" class="data row1 col3" >$3.76</td>
#     </tr>
#     <tr>
#       <th id="T_a14f3_level0_row2" class="row_heading level0 row2" >15-19</th>
#       <td id="T_a14f3_row2_col0" class="data row2 col0" >136</td>
#       <td id="T_a14f3_row2_col1" class="data row2 col1" >$3.04</td>
#       <td id="T_a14f3_row2_col2" class="data row2 col2" >$412.89</td>
#       <td id="T_a14f3_row2_col3" class="data row2 col3" >$3.86</td>
#     </tr>
#     <tr>
#       <th id="T_a14f3_level0_row3" class="row_heading level0 row3" >20-24</th>
#       <td id="T_a14f3_row3_col0" class="data row3 col0" >365</td>
#       <td id="T_a14f3_row3_col1" class="data row3 col1" >$3.05</td>
#       <td id="T_a14f3_row3_col2" class="data row3 col2" >$1114.06</td>
#       <td id="T_a14f3_row3_col3" class="data row3 col3" >$4.32</td>
#     </tr>
#     <tr>
#       <th id="T_a14f3_level0_row4" class="row_heading level0 row4" >25-29</th>
#       <td id="T_a14f3_row4_col0" class="data row4 col0" >101</td>
#       <td id="T_a14f3_row4_col1" class="data row4 col1" >$2.90</td>
#       <td id="T_a14f3_row4_col2" class="data row4 col2" >$293.00</td>
#       <td id="T_a14f3_row4_col3" class="data row4 col3" >$3.81</td>
#     </tr>
#     <tr>
#       <th id="T_a14f3_level0_row5" class="row_heading level0 row5" >30-34</th>
#       <td id="T_a14f3_row5_col0" class="data row5 col0" >73</td>
#       <td id="T_a14f3_row5_col1" class="data row5 col1" >$2.93</td>
#       <td id="T_a14f3_row5_col2" class="data row5 col2" >$214.00</td>
#       <td id="T_a14f3_row5_col3" class="data row5 col3" >$4.12</td>
#     </tr>
#     <tr>
#       <th id="T_a14f3_level0_row6" class="row_heading level0 row6" >35-39</th>
#       <td id="T_a14f3_row6_col0" class="data row6 col0" >41</td>
#       <td id="T_a14f3_row6_col1" class="data row6 col1" >$3.60</td>
#       <td id="T_a14f3_row6_col2" class="data row6 col2" >$147.67</td>
#       <td id="T_a14f3_row6_col3" class="data row6 col3" >$4.76</td>
#     </tr>
#     <tr>
#       <th id="T_a14f3_level0_row7" class="row_heading level0 row7" >40+</th>
#       <td id="T_a14f3_row7_col0" class="data row7 col0" >13</td>
#       <td id="T_a14f3_row7_col1" class="data row7 col1" >$2.94</td>
#       <td id="T_a14f3_row7_col2" class="data row7 col2" >$38.24</td>
#       <td id="T_a14f3_row7_col3" class="data row7 col3" >$3.19</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 132     Persuasion                                                9
# 108     Extraction, Quickblade Of Trembling Hands                 9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 132     Persuasion                                                 $28.99
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 103     Singed Scalpel                                             $34.80
